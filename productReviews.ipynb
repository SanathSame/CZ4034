# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('productlist.csv')
df.head()
# Out:
#    Unnamed: 0     product_ID                           product_name  \
# 0           0  6866178703429            Dew-Glow Moisturizer SPF 50
# 1           1  6857050914885                    Retinol Expert 0.1%
# 2           2  6857051275333               Bio Conditioning Essence
# 3           3  6815255330885            Best of K-Beauty 5-Step Set
# 4           4    10245844553  Licorice pH Balancing Cleansing Toner
#
#                                         product_link product_brand price  \
# 0  https://sokoglam.com/collections/skincare/prod...      NATURIUM   $22
# 1  https://sokoglam.com/collections/skincare/prod...          IOPE   $80
# 2  https://sokoglam.com/collections/skincare/prod...          IOPE   $60
# 3  https://sokoglam.com/collections/skincare/prod...     Soko Glam  $110
# 4  https://sokoglam.com/collections/skincare/prod...        ACWELL   $18
#
#                                  product_description        product_type  \
# ...

# %%
print(df['product_type'].unique())
# Out:
# ["['Sun protection']" "['Serum/Ampoule']" "['Essence']" "['Sets']"
#  "['Toner']" "['Oil_Cleanser']" "['Sheet_Masks']" "['Moisturizer']"
#  "['Spot Treatments']" "['Makeup', 'Sun protection']" "['Makeup']"
#  "['Water Cleanser']" '[]' "['Eye Care', 'Eye Creams']" "['Mists']"
#  "['Moisturizer', 'Spot Treatments']" "['Exfoliator']" "['Eye Creams']"
#  "['Sleeping Mask']" "['Mists', 'Serum/Ampoule']"
#  "['Sets', 'Sheet_Masks']" "['Hair']" "['Essence', 'Toner']"
#  "['Eye Masks']" "['Body']" "['Exfoliator', 'Oil_Cleanser']"
#  "['Wash Off Mask']" "['Mists', 'Toner']" "['Body', 'Moisturizer']"
#  "['Exfoliator', 'Wash Off Mask']" "['Essence', 'Mists']"
#  "['Exfoliator', 'Lip Treatment', 'Makeup']" "['Body', 'Serum/Ampoule']"
#  "['Exfoliator', 'Water Cleanser']" "['Tool']"
#  "['Body', 'Water Cleanser']" "['Body', 'Eye Creams']"
#  "['Lip Treatment', 'Makeup']" "['Lip Treatment']"
#  "['Moisturizer', 'Sleeping Mask']"
#  "['Eye Care', 'Eye Creams', 'Moisturizer']"
# ...
