# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import numpy as np

class Agent():
    def __init__(self) -> None:
        self.tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
        self.model = AutoModel.from_pretrained('bert-base-uncased')

    def words2vector(self, sentence: str):
        sentence = "This is an example sentence."
        tokens = self.tokenizer.tokenize(sentence)

        input_ids = self.tokenizer.convert_tokens_to_ids(tokens)
        input_ids = [self.tokenizer.cls_token_id] + input_ids + [self.tokenizer.sep_token_id]

        max_length = 64
        input_ids = input_ids + [self.tokenizer.pad_token_id] * (max_length - len(input_ids))
        input_tensor = torch.tensor([input_ids])

        with torch.no_grad():
            outputs = self.model(input_tensor)
            embedding = outputs[0][:, 0, :].numpy()

        return embedding[0]
    
model = Agent()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
df_products = pd.read_csv('productlist.csv')
df_products.drop(df_products.columns[[0, 1, 4]], axis=1, inplace=True)
df_products
# Out:
#         product_ID                           product_name product_brand  \
# 0    6866178703429            Dew-Glow Moisturizer SPF 50      NATURIUM
# 1    6857050914885                    Retinol Expert 0.1%          IOPE
# 2    6857051275333               Bio Conditioning Essence          IOPE
# 3    6815255330885            Best of K-Beauty 5-Step Set     Soko Glam
# 4      10245844553  Licorice pH Balancing Cleansing Toner        ACWELL
# ..             ...                                    ...           ...
# 548  4477084074053                 Fermentation Mask Pack        BENTON
# 549  1313135558764      Aloe Soothing Mask Pack (10 Pack)        BENTON
# 550  3935397314629            Cicaherb Restore Sheet Mask       ENATURE
# 551  1978243940421            Squalane Silk Mask (5 pack)     DR ALTHEA
# 552  3942309625925             Mugwort Calming Sheet Mask     ROUND LAB
#
#      price                                product_description  \
# 0      $22  The Dew-Glow Moisturizer SPF 50 from Naturium ...
# 1      $80  If you’re looking for a trusted retinol, look ...
# 2      $60  An iconic Korean essence known for its best se...
# 3     $110  Introducing our 2022 Best of K-Beauty®  Award ...
# 4      $18  Deep clean and brighten your skin with this sp...
# ..     ...                                                ...
# 548     $3  This premium Fermentation Mask Pack from Bento...
# 549    $24  Whether you got a little too much sun or are b...
# 550  $1.80  E Nature Cica Herb Restore Sheet Mask is now a...
# 551    $17  The Dr. Althea Squalane Silk Mask offers 360-d...
# 552     $4  Give skin sensitivities instant relief with a ...
#
#            product_type                                 skin_type  \
# 0    ['Sun protection']  ['Combination', 'Dry', 'Normal', 'Oily']
# 1     ['Serum/Ampoule']  ['Combination', 'Dry', 'Normal', 'Oily']
# 2           ['Essence']                                        []
# 3            ['Others']                           ['Dry', 'Oily']
# 4             ['Toner']  ['Combination', 'Dry', 'Normal', 'Oily']
# ..                  ...                                       ...
# 548       ['Face Mask']                 ['Combination', 'Normal']
# 549       ['Face Mask']          ['Combination', 'Dry', 'Normal']
# 550       ['Face Mask']  ['Combination', 'Dry', 'Normal', 'Oily']
# 551       ['Face Mask']                                   ['Dry']
# 552       ['Face Mask']                                        []
#
#                                           skin_concern  \
# 0         ['Anti-Aging/Wrinkles', 'Dryness/Hydration']
# 1    ['Oil Control/Pores', 'Acne', 'Anti-Aging/Wrin...
# 2         ['Anti-Aging/Wrinkles', 'Dryness/Hydration']
# 3    ['Acne', 'Anti-Aging/Wrinkles', 'Pigmentation'...
# 4    ['Acne', 'Anti-Aging/Wrinkles', 'Pigmentation'...
# ..                                                 ...
# 548  ['Anti-Aging/Wrinkles', 'Pigmentation', 'Dryne...
# 549      ['Sensitive', 'Redness', 'Dryness/Hydration']
# 550                   ['Redness', 'Dryness/Hydration']
# 551                              ['Dryness/Hydration']
# 552                              ['Acne', 'Sensitive']
#
#                                               Img_link
# 0    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 1    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 2    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 3    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 4    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# ..                                                 ...
# 548  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 549  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 550  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 551  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 552  https://cdn.shopify.com/s/files/1/0249/1218/pr...
#
# [553 rows x 9 columns]

# %%
vectorlist = []
price_num = []
for idx, row in df_products.iterrows():
    item_info = row['product_name'] + row['product_brand'] + row['price'] + row['product_description'] + row['product_type'] + row['skin_type'] + row['skin_concern']
    price_num.append(float(row['price'][1:]))
    vectorlist.append(model.words2vector(item_info))

# %%
df_products['feature_vector'] = vectorlist
df_products['price_num'] = price_num

# %%
df_products.to_json("./productlist_with_vector.json", orient="records")

# %%
df_products
# Out:
#         product_ID                           product_name product_brand  \
# 0    6866178703429            Dew-Glow Moisturizer SPF 50      NATURIUM
# 1    6857050914885                    Retinol Expert 0.1%          IOPE
# 2    6857051275333               Bio Conditioning Essence          IOPE
# 3    6815255330885            Best of K-Beauty 5-Step Set     Soko Glam
# 4      10245844553  Licorice pH Balancing Cleansing Toner        ACWELL
# ..             ...                                    ...           ...
# 548  4477084074053                 Fermentation Mask Pack        BENTON
# 549  1313135558764      Aloe Soothing Mask Pack (10 Pack)        BENTON
# 550  3935397314629            Cicaherb Restore Sheet Mask       ENATURE
# 551  1978243940421            Squalane Silk Mask (5 pack)     DR ALTHEA
# 552  3942309625925             Mugwort Calming Sheet Mask     ROUND LAB
#
#      price                                product_description  \
# 0      $22  The Dew-Glow Moisturizer SPF 50 from Naturium ...
# 1      $80  If you’re looking for a trusted retinol, look ...
# 2      $60  An iconic Korean essence known for its best se...
# 3     $110  Introducing our 2022 Best of K-Beauty®  Award ...
# 4      $18  Deep clean and brighten your skin with this sp...
# ..     ...                                                ...
# 548     $3  This premium Fermentation Mask Pack from Bento...
# 549    $24  Whether you got a little too much sun or are b...
# 550  $1.80  E Nature Cica Herb Restore Sheet Mask is now a...
# 551    $17  The Dr. Althea Squalane Silk Mask offers 360-d...
# 552     $4  Give skin sensitivities instant relief with a ...
#
#            product_type                                 skin_type  \
# 0    ['Sun protection']  ['Combination', 'Dry', 'Normal', 'Oily']
# 1     ['Serum/Ampoule']  ['Combination', 'Dry', 'Normal', 'Oily']
# 2           ['Essence']                                        []
# 3            ['Others']                           ['Dry', 'Oily']
# 4             ['Toner']  ['Combination', 'Dry', 'Normal', 'Oily']
# ..                  ...                                       ...
# 548       ['Face Mask']                 ['Combination', 'Normal']
# 549       ['Face Mask']          ['Combination', 'Dry', 'Normal']
# 550       ['Face Mask']  ['Combination', 'Dry', 'Normal', 'Oily']
# 551       ['Face Mask']                                   ['Dry']
# 552       ['Face Mask']                                        []
#
#                                           skin_concern  \
# 0         ['Anti-Aging/Wrinkles', 'Dryness/Hydration']
# 1    ['Oil Control/Pores', 'Acne', 'Anti-Aging/Wrin...
# 2         ['Anti-Aging/Wrinkles', 'Dryness/Hydration']
# 3    ['Acne', 'Anti-Aging/Wrinkles', 'Pigmentation'...
# 4    ['Acne', 'Anti-Aging/Wrinkles', 'Pigmentation'...
# ..                                                 ...
# 548  ['Anti-Aging/Wrinkles', 'Pigmentation', 'Dryne...
# 549      ['Sensitive', 'Redness', 'Dryness/Hydration']
# 550                   ['Redness', 'Dryness/Hydration']
# 551                              ['Dryness/Hydration']
# 552                              ['Acne', 'Sensitive']
#
#                                               Img_link  \
# 0    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 1    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 2    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 3    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 4    https://cdn.shopify.com/s/files/1/0249/1218/pr...
# ..                                                 ...
# 548  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 549  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 550  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 551  https://cdn.shopify.com/s/files/1/0249/1218/pr...
# 552  https://cdn.shopify.com/s/files/1/0249/1218/pr...
#
#                                         feature_vector  price_num
# 0    [-0.6399795, 0.21811089, 0.30775434, 0.6942612...       22.0
# 1    [-0.6399795, 0.21811089, 0.30775434, 0.6942612...       80.0
# 2    [-0.6399795, 0.21811089, 0.30775434, 0.6942612...       60.0
# 3    [-0.6399795, 0.21811089, 0.30775434, 0.6942612...      110.0
# 4    [-0.6399795, 0.21811089, 0.30775434, 0.6942612...       18.0
# ..                                                 ...        ...
# 548  [-0.6399795, 0.21811089, 0.30775434, 0.6942612...        3.0
# 549  [-0.6399795, 0.21811089, 0.30775434, 0.6942612...       24.0
# 550  [-0.6399795, 0.21811089, 0.30775434, 0.6942612...        1.8
# 551  [-0.6399795, 0.21811089, 0.30775434, 0.6942612...       17.0
# 552  [-0.6399795, 0.21811089, 0.30775434, 0.6942612...        4.0
#
# [553 rows x 11 columns]
